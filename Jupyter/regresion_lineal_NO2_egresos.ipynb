# %% [markdown]
# # Proyecto Relaciones Contaminantes Salud

# %% [markdown]
# # Contaminante NO2

# %%
# Se van a agrupar los registros del contaminante en semanas

# Se importan las librerias necesarias
import pandas as pd
# Se declara una variable con el nombre del contaminante a analizar
contaminante = 'NO2'
# Se declaran las columnas a extraer de la base de datos
columns = ['timestamp', contaminante]
# Se lee el archivo y los datos recuperados se guardan en 'dataframecontaminante'
dataframecontaminante = pd.read_csv('filled.csv', usecols=columns).dropna()
# Se convierten los strings a objeto datetime
strfdt = '%d-%b-%y %H'
dataframecontaminante['timestamp'] = pd.to_datetime(dataframecontaminante['timestamp'], errors = 'coerce', format=strfdt)
# Se eliminan los espacios vacios
dataframecontaminante = dataframecontaminante.dropna()
# Se acomoda el indice empezando en 0 con un incremento de 1
dataframecontaminante = dataframecontaminante.reset_index(drop=True)
# Se imprime 'dataframecontaminante'
dataframecontaminante
# Out:
#                   timestamp        NO2
# 0       1993-01-01 00:00:00   5.750000
# 1       1993-01-01 00:00:00  11.000000
# 2       1993-01-01 00:00:00   6.750000
# 3       1993-01-01 00:00:00  14.250000
# 4       1993-01-01 01:00:00   3.250000
# ...                     ...        ...
# 1130352 2018-12-31 23:00:00  21.600000
# 1130353 2018-12-31 23:00:00  31.400000
# 1130354 2018-12-31 23:00:00   8.400000
# 1130355 2018-12-31 23:00:00  11.800000
# 1130356 2018-12-31 23:00:00  59.900002
#
# [1130357 rows x 2 columns]

# %%
# Los datos de la columna 'timestamp' se vuelven a convertir a strings
dataframecontaminante['timestamp'] = dataframecontaminante['timestamp'].apply(lambda x: x.strftime('%Y-%m-%d %H'))
dataframecontaminante
# Out:
#              timestamp        NO2
# 0        1993-01-01 00   5.750000
# 1        1993-01-01 00  11.000000
# 2        1993-01-01 00   6.750000
# 3        1993-01-01 00  14.250000
# 4        1993-01-01 01   3.250000
# ...                ...        ...
# 1130352  2018-12-31 23  21.600000
# 1130353  2018-12-31 23  31.400000
# 1130354  2018-12-31 23   8.400000
# 1130355  2018-12-31 23  11.800000
# 1130356  2018-12-31 23  59.900002
#
# [1130357 rows x 2 columns]

# %% [markdown]
# # (Año 2015)

# %%
# Se guardan los datos de 'año' en 'dataframecontaminanteaño'
año = '2015'
dataframecontaminanteaño = dataframecontaminante.loc[dataframecontaminante['timestamp'].str.startswith(año)]
dataframecontaminanteaño = dataframecontaminanteaño.reset_index(drop=True)
dataframecontaminanteaño
# Out:
#            timestamp   NO2
# 0      2015-01-01 00  13.1
# 1      2015-01-01 00   8.0
# 2      2015-01-01 00   4.2
# 3      2015-01-01 00   3.7
# 4      2015-01-01 00   4.5
# ...              ...   ...
# 44482  2015-12-31 23   1.6
# 44483  2015-12-31 23   8.6
# 44484  2015-12-31 23   7.9
# 44485  2015-12-31 23   8.2
# 44486  2015-12-31 23  10.0
#
# [44487 rows x 2 columns]

# %%
# Se convierten los strings a objeto datetime
strfdt = '%Y-%m-%d %H'
dataframecontaminanteaño['timestamp'] = pd.to_datetime(dataframecontaminanteaño['timestamp'], errors = 'coerce', format=strfdt)
dataframecontaminanteaño
# Out:
#                 timestamp   NO2
# 0     2015-01-01 00:00:00  13.1
# 1     2015-01-01 00:00:00   8.0
# 2     2015-01-01 00:00:00   4.2
# 3     2015-01-01 00:00:00   3.7
# 4     2015-01-01 00:00:00   4.5
# ...                   ...   ...
# 44482 2015-12-31 23:00:00   1.6
# 44483 2015-12-31 23:00:00   8.6
# 44484 2015-12-31 23:00:00   7.9
# 44485 2015-12-31 23:00:00   8.2
# 44486 2015-12-31 23:00:00  10.0
#
# [44487 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date
# Se agrega una nueva columna con los numeros de semana
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['timestamp'].apply(lambda x: date(x.year, x.month, x.day))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: Week.fromdate(x))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: x.week)
dataframecontaminanteaño
# Out:
#                 timestamp   NO2  sem
# 0     2015-01-01 00:00:00  13.1   53
# 1     2015-01-01 00:00:00   8.0   53
# 2     2015-01-01 00:00:00   4.2   53
# 3     2015-01-01 00:00:00   3.7   53
# 4     2015-01-01 00:00:00   4.5   53
# ...                   ...   ...  ...
# 44482 2015-12-31 23:00:00   1.6   52
# 44483 2015-12-31 23:00:00   8.6   52
# 44484 2015-12-31 23:00:00   7.9   52
# 44485 2015-12-31 23:00:00   8.2   52
# 44486 2015-12-31 23:00:00  10.0   52
#
# [44487 rows x 3 columns]

# %%
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['EGRESO', 'DIAG_INI', 'ENTIDAD']
entidad = 19
csvegresos = 'EGRESO_' + año + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums).dropna()
dataframeegresosaño = dataframeegresosaño.loc[dataframeegresosaño['ENTIDAD'] == entidad]
dataframeegresosaño
# Out:
#                       EGRESO  ENTIDAD DIAG_INI
# 2721     2015-12-01 00:00:00       19     C349
# 3052     2015-08-24 00:00:00       19     C186
# 3098     2015-07-15 00:00:00       19     C509
# 3254     2015-06-18 00:00:00       19     C509
# 8651     2015-05-09 00:00:00       19     C189
# ...                      ...      ...      ...
# 2923756  2015-06-10 00:00:00       19     J342
# 2931414  2015-08-18 00:00:00       19     M190
# 2934869  2015-09-09 00:00:00       19     C229
# 2943586  2015-11-20 00:00:00       19     K801
# 2966800  2015-08-14 00:00:00       19     F322
#
# [54209 rows x 3 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S'
dataframeegresosaño['EGRESO'] = pd.to_datetime(dataframeegresosaño['EGRESO'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['EGRESO'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['EGRESO'] = dataframeegresosaño['EGRESO'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#           EGRESO  ENTIDAD DIAG_INI  sem
# 0     2015-12-01       19     C349   48
# 1     2015-08-24       19     C186   34
# 2     2015-07-15       19     C509   28
# 3     2015-06-18       19     C509   24
# 4     2015-05-09       19     C189   18
# ...          ...      ...      ...  ...
# 53336 2015-06-10       19     J342   23
# 53337 2015-08-18       19     M190   33
# 53338 2015-09-09       19     C229   36
# 53339 2015-11-20       19     K801   46
# 53340 2015-08-14       19     F322   32
#
# [53341 rows x 4 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     1068
# 2     1016
# 3     1026
# 4     1034
# 5      964
# 6     1036
# 7     1048
# 8      983
# 9      938
# 10     978
# 11     906
# 12    1011
# 13     932
# 14     978
# 15    1056
# 16    1018
# 17    1010
# 18     966
# 19    1044
# 20     988
# 21     999
# 22     977
# 23    1044
# 24    1021
# 25    1052
# 26    1022
# 27    1076
# 28    1106
# 29    1039
# 30    1060
# 31    1063
# 32    1072
# 33    1073
# 34    1087
# 35    1123
# 36    1077
# 37    1103
# 38    1105
# 39    1038
# 40    1129
# 41    1128
# 42    1117
# 43    1116
# 44    1115
# 45    1059
# 46     992
# 47    1066
# 48    1089
# 49    1106
# 50    1138
# 51     790
# 53     359
# Name: sem, dtype: int64

# %%
# Se pasa a un nuevo dataframe
dataframesemanascontaminanteaño = pd.DataFrame()
dataframesemanascontaminanteaño['sem'] = semanas.index
dataframesemanascontaminanteaño[contaminante] = ''
n = len(semanas.index)
for i in range (n):
    registrossem = dataframecontaminanteaño.loc[dataframecontaminanteaño['sem'] == i+1]
    # Se calcula el promedio por semana de las lecturas del contaminante registradas 
    promediocontaminanteañosem = registrossem[contaminante].mean()
    dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
dataframesemanascontaminanteaño
# Out:
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
# <ipython-input-9-967a018ff37a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
#     sem        NO2
# 0     1  14.521822
# 1     2    16.6357
# 2     3  17.880606
# 3     4  18.436327
# 4     5  15.193626
# 5     6  16.650748
# 6     7  15.785729
# 7     8  12.504573
# 8     9  11.399658
# 9    10  14.938685
# 10   11  12.348955
# 11   12   11.14022
# 12   13   9.097262
# 13   14   9.096333
# 14   15  11.422571
# 15   16  11.865983
# 16   17  11.062268
# 17   18    8.38982
# 18   19   7.633965
# 19   20   7.164978
# 20   21   5.964655
# 21   22   4.975676
# 22   23     4.5344
# 23   24   6.214395
# 24   25   5.127626
# 25   26   5.770446
# 26   27   5.046203
# 27   28   5.218452
# 28   29   5.592112
# 29   30   5.533653
# 30   31   5.398568
# 31   32   5.963459
# 32   33   7.791938
# 33   34   6.258931
# 34   35   6.140751
# 35   36   7.954005
# 36   37   7.381087
# 37   38   8.657039
# 38   39  12.279691
# 39   40   9.681008
# 40   41  11.850466
# 41   42   9.670766
# 42   43  14.418514
# 43   44  11.459486
# 44   45  11.011955
# 45   46  11.565287
# 46   47   9.439529
# 47   48  10.881596
# 48   49  17.418344
# 49   50  14.168058
# 50   51  17.089018
# 51   53   9.764201

# %%
# Se crea el dataframe 'diagnosticosaño' con los nombres de los diferentes diagnosticos sin repeticion
diagnosticosaño = dataframeegresosaño['DIAG_INI'].value_counts()
# Se ordena del diagnostico con mayor numero de egresos al diagnostico con menor numero de egresos
diagnosticosaño = diagnosticosaño.sort_values(ascending = False)
# Se crea el dataframe 'cies2010' con los nombres de los diagnosticos, los numeros de las semanas, 
# y la cantidad de diagnosticos de dicha enfermedad en cada semana
ciesaño = dataframeegresosaño.groupby(['DIAG_INI', 'sem']).count()

# Se importan las librerias necesarias
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import string
# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib import style
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

import numpy as np

s_scaler = preprocessing.StandardScaler()
# Se crea la lista 'ind' con los indices de las semanas empezando con el 1
ind = []
n = len(semanas.index)
for i in range (n):
    ind.append(i+1)
    
# Se guardan las letras del abdcedario en mayusculas en la lista 'letras' para la agrupación de CIEs
letras = []
for letra in string.ascii_uppercase:
    letras.append(str(letra))
# Se inicia un contador para controlar la cantidad de graficos a generar
cont = 0
maximo = 5

datacorr = []
colors = []
spoke_labels = []

# Proceso de generación de las figuras
print('\n' + año)
for name in diagnosticosaño.index:
    if cont < maximo:
        dataframegraficoañocontaminantecie = pd.DataFrame()
        dataframegraficoañocontaminantecie[contaminante] = dataframesemanascontaminanteaño[contaminante]
        dataframegraficoañocontaminantecie = dataframegraficoañocontaminantecie.reindex(ind)
        
        dataframegraficoañocontaminantecie[name] = ciesaño['EGRESO'][name]
        for i in range (n):
            dataframegraficoañocontaminantecie[contaminante][i+1] = dataframesemanascontaminanteaño[contaminante][i]
        col_names = [contaminante, name]    
        
        # MODELO DE REGRESIÓN LINEAL
        # ==============================================================================
        spoke_labels.append(col_names[1])
        datos = pd.DataFrame(dataframegraficoañocontaminantecie, columns=col_names)
        datos = (datos - datos.min()) / (datos.max() - datos.min())
        # Gráfico
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        datos.plot(
            x    = col_names[0],
            y    = col_names[1],
            c    = 'firebrick',
            kind = "scatter",
            ax   = ax
        )
        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        print('\n\n Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        
        # Correlación lineal entre las dos variables
        # ==============================================================================
        corr_test = pearsonr(x = datos[col_names[0]].fillna(0), y =  datos[col_names[1]].fillna(0))
        print("Coeficiente de correlación de Pearson: ", corr_test[0])
        print("P-value: ", corr_test[1])

        datacorr.append(abs(corr_test[0]))
        if(corr_test[0] < 0):
            colors.append('r')
        else: 
            colors.append('b')

        # División de los datos en train y test
        # ==============================================================================
        X = datos[[col_names[0]]].fillna(0)
        y = datos[col_names[1]].fillna(0)

        X_train, X_test, y_train, y_test = train_test_split(
            X.values.reshape(-1,1),
            y.values.reshape(-1,1),
            train_size   = 0.8,
            random_state = 1234,
            shuffle      = True
        )
        
        X_train = sm.add_constant(X_train, prepend=True)
        modelo = sm.OLS(endog=y_train, exog=X_train)
        modelo = modelo.fit()
        print(modelo.summary())
        
        sml = modelo.summary().as_latex()
        namefile = 'modelos_latex/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.tex'
        f = open(namefile, 'w')
        with open(namefile, 'w') as f:
            f.write(sml)

        # Intervalos de confianza para los coeficientes del modelo
        # # ==============================================================================
        modelo.conf_int(alpha=0.05)

        # Predicciones con intervalo de confianza del 95%
        # # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones.head(4)        

        # Predicciones con intervalo de confianza del 95%
        # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones['x'] = X_train[:, 1]
        predicciones['y'] = y_train
        predicciones = predicciones.sort_values('x')

        # Gráfico del modelo
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        ax.set_xlabel(col_names[0])
        ax.set_ylabel(col_names[1])
        ax.scatter(predicciones['x'], predicciones['y'], marker='o', color = "gray")
        ax.plot(predicciones['x'], predicciones["mean"], linestyle='-', label="OLS")
        ax.plot(predicciones['x'], predicciones["mean_ci_lower"], linestyle='--', color='red', label="95% CI")
        ax.plot(predicciones['x'], predicciones["mean_ci_upper"], linestyle='--', color='red')
        ax.fill_between(predicciones['x'], predicciones["mean_ci_lower"], predicciones["mean_ci_upper"], alpha=0.1)
        ax.legend()

        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.eps', format='eps')
        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.jpg', format='jpg')

        # Error de test del modelo 
        # ==============================================================================
        X_test = sm.add_constant(X_test, prepend=True)
        predicciones = modelo.predict(exog = X_test)
        rmse = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False
            )
        print("")
        vmin = abs(y_train.min())
        vmax = abs(y_train.max())
        pval = vmin + vmax
        pe = (rmse*100)/pval
        print(f"El error (rmse) de test es: {rmse}")
        print(f"El porcentaje de error de test es: {pe}")


    cont = cont+1
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 2015
#
#
#  Contaminante NO2 & CIE O809
# Coeficiente de correlación de Pearson:  -0.1792161434188607
# P-value:  0.20363909580296838
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.031
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.316
# Time:                        07:42:17   Log-Likelihood:               -0.66394
# No. Observations:                  41   AIC:                             5.328
# Df Residuals:                      39   BIC:                             8.755
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5346      0.066      8.071      0.000       0.401       0.669
# x1            -0.1348      0.133     -1.015      0.316      -0.403       0.134
# ==============================================================================
# Omnibus:                        1.106   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                0.938
# Skew:                           0.112   Prob(JB):                        0.626
# Kurtosis:                       2.294   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.19145353750032199
# El porcentaje de error de test es: 19.1453537500322
#
#
#  Contaminante NO2 & CIE O829
# Coeficiente de correlación de Pearson:  0.006982678427219141
# P-value:  0.9608162136385061
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                   0.02767
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.869
# Time:                        07:42:17   Log-Likelihood:                 2.7873
# No. Observations:                  41   AIC:                            -1.575
# Df Residuals:                      39   BIC:                             1.853
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4547      0.061      7.468      0.000       0.332       0.578
# x1             0.0203      0.122      0.166      0.869      -0.227       0.267
# ==============================================================================
# Omnibus:                        0.583   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.747   Jarque-Bera (JB):                0.701
# Skew:                          -0.172   Prob(JB):                        0.704
# Kurtosis:                       2.459   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.3067547242838657
# El porcentaje de error de test es: 34.17014650250656
#
#
#  Contaminante NO2 & CIE O759
# Coeficiente de correlación de Pearson:  0.22763197830621754
# P-value:  0.10459785988384435
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     3.827
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):             0.0576
# Time:                        07:42:17   Log-Likelihood:                 4.1867
# No. Observations:                  41   AIC:                            -4.373
# Df Residuals:                      39   BIC:                           -0.9462
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2574      0.059      4.374      0.000       0.138       0.376
# x1             0.2307      0.118      1.956      0.058      -0.008       0.469
# ==============================================================================
# Omnibus:                        6.282   Durbin-Watson:                   2.346
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                5.397
# Skew:                           0.879   Prob(JB):                       0.0673
# Kurtosis:                       3.268   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.23412401544663947
# El porcentaje de error de test es: 23.412401544663947
#
#
#  Contaminante NO2 & CIE O069
# Coeficiente de correlación de Pearson:  -0.3239851288098214
# P-value:  0.01912506048562271
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     3.574
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):             0.0661
# Time:                        07:42:17   Log-Likelihood:                 1.2953
# No. Observations:                  41   AIC:                             1.409
# Df Residuals:                      39   BIC:                             4.836
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6462      0.063     10.234      0.000       0.519       0.774
# x1            -0.2393      0.127     -1.891      0.066      -0.495       0.017
# ==============================================================================
# Omnibus:                        0.647   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.724   Jarque-Bera (JB):                0.697
# Skew:                          -0.063   Prob(JB):                        0.706
# Kurtosis:                       2.374   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.2552468212201424
# El porcentaje de error de test es: 25.52468212201424
#
#
#  Contaminante NO2 & CIE K802
# Coeficiente de correlación de Pearson:  0.18731393649524586
# P-value:  0.18361412085721385
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.044
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.313
# Time:                        07:42:18   Log-Likelihood:                 2.7252
# No. Observations:                  41   AIC:                            -1.450
# Df Residuals:                      39   BIC:                             1.977
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2992      0.061      4.907      0.000       0.176       0.423
# x1             0.1249      0.122      1.022      0.313      -0.122       0.372
# ==============================================================================
# Omnibus:                        5.110   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                4.032
# Skew:                           0.748   Prob(JB):                        0.133
# Kurtosis:                       3.346   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.2956580583043091
# El porcentaje de error de test es: 29.565805830430907

# %%
# Se importa el archivo creado
import visualization_spiderwebs

alldata = []
nd = len(datacorr)
for ii in range(nd):
    datatemp = []
    for yy in range(nd):
        if(ii==yy):
            datatemp.append(datacorr[ii])
        else: 
            datatemp.append(0)
    alldata.append(datatemp)
title = 'correlaciones_' + contaminante + '_' + año
visualization_spiderwebs.create_spiderwebs(alldata, 1, title, spoke_labels, colors, 'polygon')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # (Año 2016)

# %%
# Se guardan los datos de 'año' en 'dataframecontaminanteaño'
año = '2016'
dataframecontaminanteaño = dataframecontaminante.loc[dataframecontaminante['timestamp'].str.startswith(año)]
dataframecontaminanteaño = dataframecontaminanteaño.reset_index(drop=True)
dataframecontaminanteaño
# Out:
#            timestamp        NO2
# 0      2016-01-01 00   7.200000
# 1      2016-01-01 00   1.500000
# 2      2016-01-01 00   9.200000
# 3      2016-01-01 00   7.400000
# 4      2016-01-01 00  10.500000
# ...              ...        ...
# 37493  2016-12-31 22  25.600000
# 37494  2016-12-31 23  18.600000
# 37495  2016-12-31 23  10.900000
# 37496  2016-12-31 23  39.099998
# 37497  2016-12-31 23  11.900000
#
# [37498 rows x 2 columns]

# %%
# Se convierten los strings a objeto datetime
strfdt = '%Y-%m-%d %H'
dataframecontaminanteaño['timestamp'] = pd.to_datetime(dataframecontaminanteaño['timestamp'], errors = 'coerce', format=strfdt)
dataframecontaminanteaño
# Out:
#                 timestamp        NO2
# 0     2016-01-01 00:00:00   7.200000
# 1     2016-01-01 00:00:00   1.500000
# 2     2016-01-01 00:00:00   9.200000
# 3     2016-01-01 00:00:00   7.400000
# 4     2016-01-01 00:00:00  10.500000
# ...                   ...        ...
# 37493 2016-12-31 22:00:00  25.600000
# 37494 2016-12-31 23:00:00  18.600000
# 37495 2016-12-31 23:00:00  10.900000
# 37496 2016-12-31 23:00:00  39.099998
# 37497 2016-12-31 23:00:00  11.900000
#
# [37498 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date
# Se agrega una nueva columna con los numeros de semana
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['timestamp'].apply(lambda x: date(x.year, x.month, x.day))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: Week.fromdate(x))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: x.week)
dataframecontaminanteaño
# Out:
#                 timestamp        NO2  sem
# 0     2016-01-01 00:00:00   7.200000   52
# 1     2016-01-01 00:00:00   1.500000   52
# 2     2016-01-01 00:00:00   9.200000   52
# 3     2016-01-01 00:00:00   7.400000   52
# 4     2016-01-01 00:00:00  10.500000   52
# ...                   ...        ...  ...
# 37493 2016-12-31 22:00:00  25.600000   52
# 37494 2016-12-31 23:00:00  18.600000   52
# 37495 2016-12-31 23:00:00  10.900000   52
# 37496 2016-12-31 23:00:00  39.099998   52
# 37497 2016-12-31 23:00:00  11.900000   52
#
# [37498 rows x 3 columns]

# %%
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['EGRESO', 'DIAG_INI', 'ENTIDAD']
entidad = 19
csvegresos = 'EGRESO_' + año + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums).dropna()
dataframeegresosaño = dataframeegresosaño.loc[dataframeegresosaño['ENTIDAD'] == entidad]
dataframeegresosaño
# Out:
#                    EGRESO  ENTIDAD DIAG_INI
# 3481     04/18/2016 00:00       19     D433
# 5587     06/01/2016 00:00       19     I619
# 7319     08/18/2016 00:00       19     Q531
# 231176   10/05/2016 00:00       19     O429
# 235923   12/28/2015 00:00       19     Z980
# ...                   ...      ...      ...
# 979888   06/29/2016 00:00       19     O240
# 981083   11/08/2016 00:00       19     S407
# 981131   11/08/2016 00:00       19     S407
# 1011116  07/28/2016 00:00       19     S099
# 1028708  08/07/2016 00:00       19     O800
#
# [223 rows x 3 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%m/%d/%Y %H:%M'
dataframeegresosaño['EGRESO'] = pd.to_datetime(dataframeegresosaño['EGRESO'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['EGRESO'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['EGRESO'] = dataframeegresosaño['EGRESO'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#         EGRESO  ENTIDAD DIAG_INI  sem
# 0   2016-04-18       19     D433   16
# 1   2016-06-01       19     I619   22
# 2   2016-08-18       19     Q531   33
# 3   2016-10-05       19     O429   40
# 4   2016-12-18       19     T009   51
# ..         ...      ...      ...  ...
# 211 2016-06-29       19     O240   26
# 212 2016-11-08       19     S407   45
# 213 2016-11-08       19     S407   45
# 214 2016-07-28       19     S099   30
# 215 2016-08-07       19     O800   32
#
# [216 rows x 4 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1      5
# 2      1
# 3     11
# 4      4
# 5      6
# 6      3
# 7      1
# 8      3
# 9      7
# 10     2
# 11     4
# 12     2
# 13     1
# 14     6
# 15     6
# 16     6
# 17     3
# 18     6
# 19     6
# 20     2
# 21     3
# 22     5
# 23     5
# 24     1
# 25     7
# 26     5
# 27     4
# 28     2
# 29     2
# 30     8
# 31     2
# 32     7
# 33     6
# 34     1
# 35     2
# 36     4
# 37     5
# 38     2
# 39     5
# 40     4
# 41     2
# 42     6
# 43     4
# 44     2
# 45     7
# 46     5
# 47     2
# 48     3
# 49     3
# 50     7
# 51     6
# 52     4
# Name: sem, dtype: int64

# %%
# Se pasa a un nuevo dataframe
dataframesemanascontaminanteaño = pd.DataFrame()
dataframesemanascontaminanteaño['sem'] = semanas.index
dataframesemanascontaminanteaño[contaminante] = ''
n = len(semanas.index)
for i in range (n):
    registrossem = dataframecontaminanteaño.loc[dataframecontaminanteaño['sem'] == i+1]
    # Se calcula el promedio por semana de las lecturas del contaminante registradas 
    promediocontaminanteañosem = registrossem[contaminante].mean()
    dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
dataframesemanascontaminanteaño
# Out:
#     sem        NO2
# 0     1  11.772687
# 1     2  13.813201
# 2     3  14.865807
# 3     4  14.770274
# 4     5  11.957084
# 5     6  14.050335
# 6     7  12.100422
# 7     8   9.245718
# 8     9  10.380658
# 9    10  11.376357
# 10   11  13.843165
# 11   12   9.102977
# 12   13  11.913092
# 13   14   10.05595
# 14   15    9.34493
# 15   16   9.166435
# 16   17  11.715362
# 17   18  10.201738
# 18   19   9.195822
# 19   20   9.752249
# 20   21  10.689423
# 21   22  11.095629
# 22   23  11.099701
# 23   24   9.597492
# 24   25    7.81446
# 25   26   9.734043
# 26   27   9.655945
# 27   28   9.176749
# 28   29   7.114447
# 29   30   7.703012
# 30   31   6.563907
# 31   32       7.18
# 32   33   8.469416
# 33   34   7.525051
# 34   35   9.530021
# 35   36   8.809491
# 36   37   9.876981
# 37   38    9.12519
# 38   39  10.446781
# 39   40  10.622903
# 40   41  10.303163
# 41   42  10.841897
# 42   43  10.626348
# 43   44   8.769691
# 44   45   9.700325
# 45   46  10.739689
# 46   47  10.383616
# 47   48   9.633545
# 48   49   8.513253
# 49   50  10.797917
# 50   51  12.084821
# 51   52  10.251235

# %%
# Se crea el dataframe 'diagnosticosaño' con los nombres de los diferentes diagnosticos sin repeticion
diagnosticosaño = dataframeegresosaño['DIAG_INI'].value_counts()
# Se ordena del diagnostico con mayor numero de egresos al diagnostico con menor numero de egresos
diagnosticosaño = diagnosticosaño.sort_values(ascending = False)
# Se crea el dataframe 'cies2010' con los nombres de los diagnosticos, los numeros de las semanas, 
# y la cantidad de diagnosticos de dicha enfermedad en cada semana
ciesaño = dataframeegresosaño.groupby(['DIAG_INI', 'sem']).count()

# Se importan las librerias necesarias
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import string
# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib import style
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

import numpy as np

s_scaler = preprocessing.StandardScaler()
# Se crea la lista 'ind' con los indices de las semanas empezando con el 1
ind = []
n = len(semanas.index)
for i in range (n):
    ind.append(i+1)
    
# Se guardan las letras del abdcedario en mayusculas en la lista 'letras' para la agrupación de CIEs
letras = []
for letra in string.ascii_uppercase:
    letras.append(str(letra))
# Se inicia un contador para controlar la cantidad de graficos a generar
cont = 0
maximo = 5

datacorr = []
colors = []
spoke_labels = []

# Proceso de generación de las figuras
print('\n' + año)
for name in diagnosticosaño.index:
    if cont < maximo:
        dataframegraficoañocontaminantecie = pd.DataFrame()
        dataframegraficoañocontaminantecie[contaminante] = dataframesemanascontaminanteaño[contaminante]
        dataframegraficoañocontaminantecie = dataframegraficoañocontaminantecie.reindex(ind)
        
        dataframegraficoañocontaminantecie[name] = ciesaño['EGRESO'][name]
        for i in range (n):
            dataframegraficoañocontaminantecie[contaminante][i+1] = dataframesemanascontaminanteaño[contaminante][i]
        col_names = [contaminante, name]    
        
        # MODELO DE REGRESIÓN LINEAL
        # ==============================================================================
        dataframegraficoañocontaminantecie = dataframegraficoañocontaminantecie.fillna(0)
        spoke_labels.append(col_names[1])
        datos = pd.DataFrame(dataframegraficoañocontaminantecie, columns=col_names)
        datos = (datos - datos.min()) / (datos.max() - datos.min())
        # Gráfico
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        datos.plot(
            x    = col_names[0],
            y    = col_names[1],
            c    = 'firebrick',
            kind = "scatter",
            ax   = ax
        )
        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        print('\n\n Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        
        # Correlación lineal entre las dos variables
        # ==============================================================================
        corr_test = pearsonr(x = datos[col_names[0]].fillna(0), y =  datos[col_names[1]].fillna(0))
        print("Coeficiente de correlación de Pearson: ", corr_test[0])
        print("P-value: ", corr_test[1])

        datacorr.append(abs(corr_test[0]))
        if(corr_test[0] < 0):
            colors.append('r')
        else: 
            colors.append('b')

        # División de los datos en train y test
        # ==============================================================================
        X = datos[[col_names[0]]].fillna(0)
        y = datos[col_names[1]].fillna(0)

        X_train, X_test, y_train, y_test = train_test_split(
            X.values.reshape(-1,1),
            y.values.reshape(-1,1),
            train_size   = 0.8,
            random_state = 1234,
            shuffle      = True
        )
        
        X_train = sm.add_constant(X_train, prepend=True)
        modelo = sm.OLS(endog=y_train, exog=X_train)
        modelo = modelo.fit()
        print(modelo.summary())
        
        sml = modelo.summary().as_latex()
        namefile = 'modelos_latex/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.tex'
        f = open(namefile, 'w')
        with open(namefile, 'w') as f:
            f.write(sml)

        # Intervalos de confianza para los coeficientes del modelo
        # # ==============================================================================
        modelo.conf_int(alpha=0.05)

        # Predicciones con intervalo de confianza del 95%
        # # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones.head(4)        

        # Predicciones con intervalo de confianza del 95%
        # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones['x'] = X_train[:, 1]
        predicciones['y'] = y_train
        predicciones = predicciones.sort_values('x')

        # Gráfico del modelo
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        ax.set_xlabel(col_names[0])
        ax.set_ylabel(col_names[1])
        ax.scatter(predicciones['x'], predicciones['y'], marker='o', color = "gray")
        ax.plot(predicciones['x'], predicciones["mean"], linestyle='-', label="OLS")
        ax.plot(predicciones['x'], predicciones["mean_ci_lower"], linestyle='--', color='red', label="95% CI")
        ax.plot(predicciones['x'], predicciones["mean_ci_upper"], linestyle='--', color='red')
        ax.fill_between(predicciones['x'], predicciones["mean_ci_lower"], predicciones["mean_ci_upper"], alpha=0.1)
        ax.legend()

        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.eps', format='eps')
        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.jpg', format='jpg')

        # Error de test del modelo 
        # ==============================================================================
        X_test = sm.add_constant(X_test, prepend=True)
        predicciones = modelo.predict(exog = X_test)
        rmse = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False
            )
        print("")
        vmin = abs(y_train.min())
        vmax = abs(y_train.max())
        pval = vmin + vmax
        pe = (rmse*100)/pval
        print(f"El error (rmse) de test es: {rmse}")
        print(f"El porcentaje de error de test es: {pe}")


    cont = cont+1
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 2016
#
#
#  Contaminante NO2 & CIE F200
# Coeficiente de correlación de Pearson:  -0.1066643214230033
# P-value:  0.45167792742026347
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.5319
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.470
# Time:                        07:42:21   Log-Likelihood:                -8.1543
# No. Observations:                  41   AIC:                             20.31
# Df Residuals:                      39   BIC:                             23.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2110      0.100      2.100      0.042       0.008       0.414
# x1            -0.1454      0.199     -0.729      0.470      -0.549       0.258
# ==============================================================================
# Omnibus:                       22.841   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.408
# Skew:                           1.842   Prob(JB):                     1.51e-07
# Kurtosis:                       5.194   Cond. No.                         5.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.14824653051750863
# El porcentaje de error de test es: 14.824653051750863
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  Contaminante NO2 & CIE O809
# Coeficiente de correlación de Pearson:  0.018740783093553995
# P-value:  0.8950886537745338
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                 0.0001185
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.991
# Time:                        07:42:22   Log-Likelihood:                -20.227
# No. Observations:                  41   AIC:                             44.45
# Df Residuals:                      39   BIC:                             47.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1938      0.135      1.437      0.159      -0.079       0.467
# x1             0.0029      0.268      0.011      0.991      -0.539       0.544
# ==============================================================================
# Omnibus:                       14.201   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.408
# Skew:                           1.539   Prob(JB):                     0.000274
# Kurtosis:                       3.367   Cond. No.                         5.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.38587029967906167
# El porcentaje de error de test es: 38.58702996790617
#
#
#  Contaminante NO2 & CIE F312
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Coeficiente de correlación de Pearson:  0.0363383710213984
# P-value:  0.7981406208760677
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.2165
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.644
# Time:                        07:42:22   Log-Likelihood:                 8.4614
# No. Observations:                  41   AIC:                            -12.92
# Df Residuals:                      39   BIC:                            -9.496
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0335      0.067      0.500      0.620      -0.102       0.169
# x1             0.0619      0.133      0.465      0.644      -0.207       0.331
# ==============================================================================
# Omnibus:                       52.611   Durbin-Watson:                   2.200
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              243.012
# Skew:                           3.247   Prob(JB):                     1.70e-53
# Kurtosis:                      13.004   Cond. No.                         5.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.1473431702433798
# El porcentaje de error de test es: 14.734317024337981
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  Contaminante NO2 & CIE C029
# Coeficiente de correlación de Pearson:  -0.18868735015543647
# P-value:  0.18036330083228086
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.151
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.290
# Time:                        07:42:22   Log-Likelihood:                 33.783
# No. Observations:                  41   AIC:                            -63.57
# Df Residuals:                      39   BIC:                            -60.14
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0586      0.036      1.622      0.113      -0.014       0.132
# x1            -0.0769      0.072     -1.073      0.290      -0.222       0.068
# ==============================================================================
# Omnibus:                       64.625   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              470.998
# Skew:                           3.999   Prob(JB):                    5.30e-103
# Kurtosis:                      17.551   Cond. No.                         5.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.32372678702571284
# El porcentaje de error de test es: 64.74535740514257
#
#
#  Contaminante NO2 & CIE F710
# Coeficiente de correlación de Pearson:  -0.15386165275765415
# P-value:  0.27613553770087673
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.059
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.310
# Time:                        07:42:22   Log-Likelihood:                 14.847
# No. Observations:                  41   AIC:                            -25.69
# Df Residuals:                      39   BIC:                            -22.27
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0887      0.057      1.546      0.130      -0.027       0.205
# x1            -0.1171      0.114     -1.029      0.310      -0.347       0.113
# ==============================================================================
# Omnibus:                       75.667   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              954.516
# Skew:                           4.657   Prob(JB):                    5.36e-208
# Kurtosis:                      24.725   Cond. No.                         5.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.19877015352816851
# El porcentaje de error de test es: 19.87701535281685

# %%
# Se importa el archivo creado
import visualization_spiderwebs

alldata = []
nd = len(datacorr)
for ii in range(nd):
    datatemp = []
    for yy in range(nd):
        if(ii==yy):
            datatemp.append(datacorr[ii])
        else: 
            datatemp.append(0)
    alldata.append(datatemp)
title = 'correlaciones_' + contaminante + '_' + año
visualization_spiderwebs.create_spiderwebs(alldata, 1, title, spoke_labels, colors, 'polygon')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # (Año 2017)

# %%
# Se guardan los datos de 'año' en 'dataframecontaminanteaño'
año = '2017'
dataframecontaminanteaño = dataframecontaminante.loc[dataframecontaminante['timestamp'].str.startswith(año)]
dataframecontaminanteaño = dataframecontaminanteaño.reset_index(drop=True)
dataframecontaminanteaño
# Out:
#            timestamp   NO2
# 0      2017-01-01 00  15.1
# 1      2017-01-01 00   9.7
# 2      2017-01-01 00  35.2
# 3      2017-01-01 00  20.1
# 4      2017-01-01 01  11.7
# ...              ...   ...
# 44446  2017-12-31 23  13.1
# 44447  2017-12-31 23  10.4
# 44448  2017-12-31 23  17.0
# 44449  2017-12-31 23   5.0
# 44450  2017-12-31 23   4.4
#
# [44451 rows x 2 columns]

# %%
# Se convierten los strings a objeto datetime
strfdt = '%Y-%m-%d %H'
dataframecontaminanteaño['timestamp'] = pd.to_datetime(dataframecontaminanteaño['timestamp'], errors = 'coerce', format=strfdt)
dataframecontaminanteaño
# Out:
#                 timestamp   NO2
# 0     2017-01-01 00:00:00  15.1
# 1     2017-01-01 00:00:00   9.7
# 2     2017-01-01 00:00:00  35.2
# 3     2017-01-01 00:00:00  20.1
# 4     2017-01-01 01:00:00  11.7
# ...                   ...   ...
# 44446 2017-12-31 23:00:00  13.1
# 44447 2017-12-31 23:00:00  10.4
# 44448 2017-12-31 23:00:00  17.0
# 44449 2017-12-31 23:00:00   5.0
# 44450 2017-12-31 23:00:00   4.4
#
# [44451 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date
# Se agrega una nueva columna con los numeros de semana
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['timestamp'].apply(lambda x: date(x.year, x.month, x.day))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: Week.fromdate(x))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: x.week)
dataframecontaminanteaño
# Out:
#                 timestamp   NO2  sem
# 0     2017-01-01 00:00:00  15.1    1
# 1     2017-01-01 00:00:00   9.7    1
# 2     2017-01-01 00:00:00  35.2    1
# 3     2017-01-01 00:00:00  20.1    1
# 4     2017-01-01 01:00:00  11.7    1
# ...                   ...   ...  ...
# 44446 2017-12-31 23:00:00  13.1    1
# 44447 2017-12-31 23:00:00  10.4    1
# 44448 2017-12-31 23:00:00  17.0    1
# 44449 2017-12-31 23:00:00   5.0    1
# 44450 2017-12-31 23:00:00   4.4    1
#
# [44451 rows x 3 columns]

# %%
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['EGRESO', 'DIAG_INI', 'ENTIDAD']
entidad = 19
csvegresos = 'EGRESO_' + año + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, sep='|', usecols=colums).dropna()
dataframeegresosaño = dataframeegresosaño.loc[dataframeegresosaño['ENTIDAD'] == entidad]
dataframeegresosaño
# Out:
#                       EGRESO  ENTIDAD DIAG_INI
# 9836     2017-02-07 00:00:00       19     F120
# 11959    2017-10-24 00:00:00       19     E104
# 25534    2017-05-26 00:00:00       19     O680
# 27114    2017-04-14 00:00:00       19     T634
# 37193    2017-03-18 00:00:00       19     Q248
# ...                      ...      ...      ...
# 2720507  2017-08-21 00:00:00       19     N61X
# 2723613  2017-11-05 00:00:00       19     O809
# 2726650  2017-07-22 00:00:00       19     O809
# 2727207  2017-12-09 00:00:00       19     O809
# 2728404  2017-09-22 00:00:00       19     O621
#
# [56169 rows x 3 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S'
dataframeegresosaño['EGRESO'] = pd.to_datetime(dataframeegresosaño['EGRESO'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['EGRESO'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['EGRESO'] = dataframeegresosaño['EGRESO'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#           EGRESO  ENTIDAD DIAG_INI  sem
# 0     2017-02-07       19     F120    6
# 1     2017-10-24       19     E104   43
# 2     2017-05-26       19     O680   21
# 3     2017-04-14       19     T634   15
# 4     2017-03-18       19     Q248   11
# ...          ...      ...      ...  ...
# 56164 2017-08-21       19     N61X   34
# 56165 2017-11-05       19     O809   45
# 56166 2017-07-22       19     O809   29
# 56167 2017-12-09       19     O809   49
# 56168 2017-09-22       19     O621   38
#
# [56169 rows x 4 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     1199
# 2     1069
# 3     1051
# 4     1048
# 5     1038
# 6     1014
# 7     1053
# 8     1011
# 9     1039
# 10    1110
# 11    1068
# 12    1016
# 13    1030
# 14     978
# 15     965
# 16     959
# 17     954
# 18     989
# 19     943
# 20    1134
# 21    1016
# 22     968
# 23    1105
# 24    1147
# 25    1033
# 26    1040
# 27    1142
# 28    1025
# 29    1118
# 30    1178
# 31    1138
# 32    1100
# 33    1203
# 34    1114
# 35    1160
# 36    1178
# 37    1128
# 38    1145
# 39    1113
# 40    1169
# 41    1237
# 42    1129
# 43    1105
# 44    1121
# 45    1133
# 46    1149
# 47    1121
# 48    1139
# 49    1132
# 50    1057
# 51    1054
# 52     904
# Name: sem, dtype: int64

# %%
# Se pasa a un nuevo dataframe
dataframesemanascontaminanteaño = pd.DataFrame()
dataframesemanascontaminanteaño['sem'] = semanas.index
dataframesemanascontaminanteaño[contaminante] = ''
n = len(semanas.index)
for i in range (n):
    registrossem = dataframecontaminanteaño.loc[dataframecontaminanteaño['sem'] == i+1]
    # Se calcula el promedio por semana de las lecturas del contaminante registradas 
    promediocontaminanteañosem = registrossem[contaminante].mean()
    dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
dataframesemanascontaminanteaño
# Out:
#     sem        NO2
# 0     1  11.965543
# 1     2  14.216717
# 2     3  10.971231
# 3     4  13.054331
# 4     5  13.879758
# 5     6  13.226197
# 6     7  12.077278
# 7     8  15.904427
# 8     9   13.32685
# 9    10  13.533754
# 10   11  12.851653
# 11   12  11.993599
# 12   13  13.652824
# 13   14  11.413517
# 14   15   7.966337
# 15   16  10.156174
# 16   17  12.860582
# 17   18  12.105714
# 18   19  11.719799
# 19   20    9.68588
# 20   21  11.439707
# 21   22  10.307761
# 22   23  11.001134
# 23   24  10.218226
# 24   25  10.939375
# 25   26      9.167
# 26   27        7.9
# 27   28   8.392819
# 28   29   9.260819
# 29   30   8.418182
# 30   31  10.751587
# 31   32   9.418436
# 32   33   8.474277
# 33   34   7.343501
# 34   35   9.005696
# 35   36   9.137106
# 36   37  11.408192
# 37   38   6.049306
# 38   39   6.906636
# 39   40   9.524752
# 40   41  11.799611
# 41   42  13.572835
# 42   43  13.183562
# 43   44  17.376802
# 44   45  14.783001
# 45   46  15.453971
# 46   47  20.984369
# 47   48  16.347561
# 48   49  15.386175
# 49   50  23.216395
# 50   51  23.015451
# 51   52  16.758462

# %%
# Se crea el dataframe 'diagnosticosaño' con los nombres de los diferentes diagnosticos sin repeticion
diagnosticosaño = dataframeegresosaño['DIAG_INI'].value_counts()
# Se ordena del diagnostico con mayor numero de egresos al diagnostico con menor numero de egresos
diagnosticosaño = diagnosticosaño.sort_values(ascending = False)
# Se crea el dataframe 'cies2010' con los nombres de los diagnosticos, los numeros de las semanas, 
# y la cantidad de diagnosticos de dicha enfermedad en cada semana
ciesaño = dataframeegresosaño.groupby(['DIAG_INI', 'sem']).count()

# Se importan las librerias necesarias
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import string
# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib import style
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

import numpy as np

s_scaler = preprocessing.StandardScaler()
# Se crea la lista 'ind' con los indices de las semanas empezando con el 1
ind = []
n = len(semanas.index)
for i in range (n):
    ind.append(i+1)
    
# Se guardan las letras del abdcedario en mayusculas en la lista 'letras' para la agrupación de CIEs
letras = []
for letra in string.ascii_uppercase:
    letras.append(str(letra))
# Se inicia un contador para controlar la cantidad de graficos a generar
cont = 0
maximo = 5

datacorr = []
colors = []
spoke_labels = []

# Proceso de generación de las figuras
print('\n' + año)
for name in diagnosticosaño.index:
    if cont < maximo:
        dataframegraficoañocontaminantecie = pd.DataFrame()
        dataframegraficoañocontaminantecie[contaminante] = dataframesemanascontaminanteaño[contaminante]
        dataframegraficoañocontaminantecie = dataframegraficoañocontaminantecie.reindex(ind)
        
        dataframegraficoañocontaminantecie[name] = ciesaño['EGRESO'][name]
        for i in range (n):
            dataframegraficoañocontaminantecie[contaminante][i+1] = dataframesemanascontaminanteaño[contaminante][i]
        col_names = [contaminante, name]    
        
        # MODELO DE REGRESIÓN LINEAL
        # ==============================================================================
        spoke_labels.append(col_names[1])
        datos = pd.DataFrame(dataframegraficoañocontaminantecie, columns=col_names)
        datos = (datos - datos.min()) / (datos.max() - datos.min())
        # Gráfico
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        datos.plot(
            x    = col_names[0],
            y    = col_names[1],
            c    = 'firebrick',
            kind = "scatter",
            ax   = ax
        )
        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        print('\n\n Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        
        # Correlación lineal entre las dos variables
        # ==============================================================================
        corr_test = pearsonr(x = datos[col_names[0]].fillna(0), y =  datos[col_names[1]].fillna(0))
        print("Coeficiente de correlación de Pearson: ", corr_test[0])
        print("P-value: ", corr_test[1])

        datacorr.append(abs(corr_test[0]))
        if(corr_test[0] < 0):
            colors.append('r')
        else: 
            colors.append('b')

        # División de los datos en train y test
        # ==============================================================================
        X = datos[[col_names[0]]].fillna(0)
        y = datos[col_names[1]].fillna(0)

        X_train, X_test, y_train, y_test = train_test_split(
            X.values.reshape(-1,1),
            y.values.reshape(-1,1),
            train_size   = 0.8,
            random_state = 1234,
            shuffle      = True
        )
        
        X_train = sm.add_constant(X_train, prepend=True)
        modelo = sm.OLS(endog=y_train, exog=X_train)
        modelo = modelo.fit()
        print(modelo.summary())
        
        sml = modelo.summary().as_latex()
        namefile = 'modelos_latex/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.tex'
        f = open(namefile, 'w')
        with open(namefile, 'w') as f:
            f.write(sml)

        # Intervalos de confianza para los coeficientes del modelo
        # # ==============================================================================
        modelo.conf_int(alpha=0.05)

        # Predicciones con intervalo de confianza del 95%
        # # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones.head(4)        

        # Predicciones con intervalo de confianza del 95%
        # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones['x'] = X_train[:, 1]
        predicciones['y'] = y_train
        predicciones = predicciones.sort_values('x')

        # Gráfico del modelo
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        ax.set_xlabel(col_names[0])
        ax.set_ylabel(col_names[1])
        ax.scatter(predicciones['x'], predicciones['y'], marker='o', color = "gray")
        ax.plot(predicciones['x'], predicciones["mean"], linestyle='-', label="OLS")
        ax.plot(predicciones['x'], predicciones["mean_ci_lower"], linestyle='--', color='red', label="95% CI")
        ax.plot(predicciones['x'], predicciones["mean_ci_upper"], linestyle='--', color='red')
        ax.fill_between(predicciones['x'], predicciones["mean_ci_lower"], predicciones["mean_ci_upper"], alpha=0.1)
        ax.legend()

        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.eps', format='eps')
        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.jpg', format='jpg')

        # Error de test del modelo 
        # ==============================================================================
        X_test = sm.add_constant(X_test, prepend=True)
        predicciones = modelo.predict(exog = X_test)
        rmse = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False
            )
        print("")
        vmin = abs(y_train.min())
        vmax = abs(y_train.max())
        pval = vmin + vmax
        pe = (rmse*100)/pval
        print(f"El error (rmse) de test es: {rmse}")
        print(f"El porcentaje de error de test es: {pe}")


    cont = cont+1
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 2017
#
#
#  Contaminante NO2 & CIE O809
# Coeficiente de correlación de Pearson:  -0.13831758264528207
# P-value:  0.32813035251626427
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     2.661
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.111
# Time:                        07:42:28   Log-Likelihood:               -0.40315
# No. Observations:                  41   AIC:                             4.806
# Df Residuals:                      39   BIC:                             8.233
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6125      0.079      7.736      0.000       0.452       0.773
# x1            -0.3339      0.205     -1.631      0.111      -0.748       0.080
# ==============================================================================
# Omnibus:                        2.914   Durbin-Watson:                   1.474
# Prob(Omnibus):                  0.233   Jarque-Bera (JB):                1.471
# Skew:                           0.026   Prob(JB):                        0.479
# Kurtosis:                       2.073   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.2860285534213886
# El porcentaje de error de test es: 26.752082349412227
#
#
#  Contaminante NO2 & CIE O829
# Coeficiente de correlación de Pearson:  -0.09678335390386597
# P-value:  0.4948886610069293
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.1283
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.722
# Time:                        07:42:28   Log-Likelihood:                 1.2875
# No. Observations:                  41   AIC:                             1.425
# Df Residuals:                      39   BIC:                             4.852
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5122      0.076      6.742      0.000       0.359       0.666
# x1             0.0704      0.196      0.358      0.722      -0.327       0.468
# ==============================================================================
# Omnibus:                        0.284   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.867   Jarque-Bera (JB):                0.472
# Skew:                          -0.061   Prob(JB):                        0.790
# Kurtosis:                       2.489   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.2461226796238374
# El porcentaje de error de test es: 24.61226796238374
#
#
#  Contaminante NO2 & CIE O759
# Coeficiente de correlación de Pearson:  -0.09416446278530746
# P-value:  0.5066897748299906
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.592
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.215
# Time:                        07:42:28   Log-Likelihood:                 18.932
# No. Observations:                  41   AIC:                            -33.86
# Df Residuals:                      39   BIC:                            -30.44
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4295      0.049      8.692      0.000       0.330       0.529
# x1            -0.1612      0.128     -1.262      0.215      -0.420       0.097
# ==============================================================================
# Omnibus:                        0.371   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.831   Jarque-Bera (JB):                0.537
# Skew:                           0.156   Prob(JB):                        0.765
# Kurtosis:                       2.535   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.27186879788796736
# El porcentaje de error de test es: 35.116386393862456
#
#
#  Contaminante NO2 & CIE O069
# Coeficiente de correlación de Pearson:  -0.39874506240987384
# P-value:  0.0034115733642952027
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     4.215
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):             0.0468
# Time:                        07:42:28   Log-Likelihood:                 3.3135
# No. Observations:                  41   AIC:                            -2.627
# Df Residuals:                      39   BIC:                            0.8002
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5543      0.072      7.664      0.000       0.408       0.701
# x1            -0.3839      0.187     -2.053      0.047      -0.762      -0.006
# ==============================================================================
# Omnibus:                        4.528   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.104   Jarque-Bera (JB):                4.082
# Skew:                           0.770   Prob(JB):                        0.130
# Kurtosis:                       2.870   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.1716874683114417
# El porcentaje de error de test es: 17.16874683114417
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  Contaminante NO2 & CIE K802
# Coeficiente de correlación de Pearson:  0.1324854835642333
# P-value:  0.3491298492187725
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9679
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.331
# Time:                        07:42:28   Log-Likelihood:                 4.8349
# No. Observations:                  41   AIC:                            -5.670
# Df Residuals:                      39   BIC:                            -2.243
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4860      0.070      6.974      0.000       0.345       0.627
# x1             0.1772      0.180      0.984      0.331      -0.187       0.542
# ==============================================================================
# Omnibus:                        0.986   Durbin-Watson:                   2.524
# Prob(Omnibus):                  0.611   Jarque-Bera (JB):                0.951
# Skew:                          -0.340   Prob(JB):                        0.622
# Kurtosis:                       2.692   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.2804830210710675
# El porcentaje de error de test es: 29.606541113057126

# %%
# Se importa el archivo creado
import visualization_spiderwebs

alldata = []
nd = len(datacorr)
for ii in range(nd):
    datatemp = []
    for yy in range(nd):
        if(ii==yy):
            datatemp.append(datacorr[ii])
        else: 
            datatemp.append(0)
    alldata.append(datatemp)
title = 'correlaciones_' + contaminante + '_' + año
visualization_spiderwebs.create_spiderwebs(alldata, 1, title, spoke_labels, colors, 'polygon')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # (Año 2018)

# %%
# Se guardan los datos de 'año' en 'dataframecontaminanteaño'
año = '2018'
dataframecontaminanteaño = dataframecontaminante.loc[dataframecontaminante['timestamp'].str.startswith(año)]
dataframecontaminanteaño = dataframecontaminanteaño.reset_index(drop=True)
dataframecontaminanteaño
# Out:
#            timestamp        NO2
# 0      2018-01-01 01   2.900000
# 1      2018-01-01 01  15.200000
# 2      2018-01-01 01   2.900000
# 3      2018-01-01 01  17.800000
# 4      2018-01-01 01   3.600000
# ...              ...        ...
# 41615  2018-12-31 23  21.600000
# 41616  2018-12-31 23  31.400000
# 41617  2018-12-31 23   8.400000
# 41618  2018-12-31 23  11.800000
# 41619  2018-12-31 23  59.900002
#
# [41620 rows x 2 columns]

# %%
# Se convierten los strings a objeto datetime
strfdt = '%Y-%m-%d %H'
dataframecontaminanteaño['timestamp'] = pd.to_datetime(dataframecontaminanteaño['timestamp'], errors = 'coerce', format=strfdt)
dataframecontaminanteaño
# Out:
#                 timestamp        NO2
# 0     2018-01-01 01:00:00   2.900000
# 1     2018-01-01 01:00:00  15.200000
# 2     2018-01-01 01:00:00   2.900000
# 3     2018-01-01 01:00:00  17.800000
# 4     2018-01-01 01:00:00   3.600000
# ...                   ...        ...
# 41615 2018-12-31 23:00:00  21.600000
# 41616 2018-12-31 23:00:00  31.400000
# 41617 2018-12-31 23:00:00   8.400000
# 41618 2018-12-31 23:00:00  11.800000
# 41619 2018-12-31 23:00:00  59.900002
#
# [41620 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date
# Se agrega una nueva columna con los numeros de semana
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['timestamp'].apply(lambda x: date(x.year, x.month, x.day))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: Week.fromdate(x))
dataframecontaminanteaño['sem'] = dataframecontaminanteaño['sem'].apply(lambda x: x.week)
dataframecontaminanteaño
# Out:
#                 timestamp        NO2  sem
# 0     2018-01-01 01:00:00   2.900000    1
# 1     2018-01-01 01:00:00  15.200000    1
# 2     2018-01-01 01:00:00   2.900000    1
# 3     2018-01-01 01:00:00  17.800000    1
# 4     2018-01-01 01:00:00   3.600000    1
# ...                   ...        ...  ...
# 41615 2018-12-31 23:00:00  21.600000    1
# 41616 2018-12-31 23:00:00  31.400000    1
# 41617 2018-12-31 23:00:00   8.400000    1
# 41618 2018-12-31 23:00:00  11.800000    1
# 41619 2018-12-31 23:00:00  59.900002    1
#
# [41620 rows x 3 columns]

# %%
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['EGRESO', 'DIAG_INI', 'ENTIDAD']
entidad = 19
csvegresos = 'EGRESO_' + año + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums).dropna()
dataframeegresosaño = dataframeegresosaño.loc[dataframeegresosaño['ENTIDAD'] == entidad]
dataframeegresosaño
# Out:
#                           EGRESO  ENTIDAD DIAG_INI
# 3678     2018-11-15 00:00:00.000       19     N189
# 3709     2018-08-30 00:00:00.000       19     G562
# 7046     2018-05-21 00:00:00.000       19     E145
# 19178    2018-04-26 00:00:00.000       19     P073
# 100477   2018-08-28 00:00:00.000       19     F191
# ...                          ...      ...      ...
# 2603999  2018-09-12 00:00:00.000       19     J459
# 2604006  2018-04-05 00:00:00.000       19     S729
# 2616019  2018-04-10 00:00:00.000       19     R101
# 2617800  2018-07-18 00:00:00.000       19     C505
# 2622287  2018-01-27 00:00:00.000       19     I679
#
# [54471 rows x 3 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S.000'
dataframeegresosaño['EGRESO'] = pd.to_datetime(dataframeegresosaño['EGRESO'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['EGRESO'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['EGRESO'] = dataframeegresosaño['EGRESO'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#           EGRESO  ENTIDAD DIAG_INI  sem
# 0     2018-11-15       19     N189   46
# 1     2018-08-30       19     G562   35
# 2     2018-05-21       19     E145   21
# 3     2018-04-26       19     P073   17
# 4     2018-08-28       19     F191   35
# ...          ...      ...      ...  ...
# 54466 2018-09-12       19     J459   37
# 54467 2018-04-05       19     S729   14
# 54468 2018-04-10       19     R101   15
# 54469 2018-07-18       19     C505   29
# 54470 2018-01-27       19     I679    4
#
# [54471 rows x 4 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     1014
# 2     1037
# 3     1081
# 4      984
# 5     1056
# 6      994
# 7     1057
# 8     1078
# 9     1039
# 10    1023
# 11    1098
# 12     977
# 13    1015
# 14    1024
# 15    1048
# 16    1092
# 17    1049
# 18     908
# 19     997
# 20     980
# 21    1054
# 22    1004
# 23    1087
# 24    1073
# 25    1008
# 26    1082
# 27    1074
# 28    1036
# 29    1056
# 30    1068
# 31    1118
# 32    1108
# 33    1083
# 34    1079
# 35    1136
# 36    1055
# 37    1157
# 38    1163
# 39    1179
# 40    1123
# 41    1192
# 42    1061
# 43    1082
# 44    1002
# 45    1073
# 46    1069
# 47     990
# 48     994
# 49     995
# 50     937
# 51     973
# 52     809
# Name: sem, dtype: int64

# %%
# Se pasa a un nuevo dataframe
dataframesemanascontaminanteaño = pd.DataFrame()
dataframesemanascontaminanteaño['sem'] = semanas.index
dataframesemanascontaminanteaño[contaminante] = ''
n = len(semanas.index)
for i in range (n):
    registrossem = dataframecontaminanteaño.loc[dataframecontaminanteaño['sem'] == i+1]
    # Se calcula el promedio por semana de las lecturas del contaminante registradas 
    promediocontaminanteañosem = registrossem[contaminante].mean()
    dataframesemanascontaminanteaño[contaminante][i] = promediocontaminanteañosem
dataframesemanascontaminanteaño
# Out:
#     sem        NO2
# 0     1   16.23237
# 1     2  20.330123
# 2     3  17.723694
# 3     4  17.324397
# 4     5  18.167679
# 5     6  17.848679
# 6     7  18.395095
# 7     8  16.663573
# 8     9  13.786121
# 9    10  11.613287
# 10   11  10.730493
# 11   12  11.159588
# 12   13    10.8244
# 13   14  13.027572
# 14   15  10.943769
# 15   16  10.676446
# 16   17    9.53209
# 17   18  13.377899
# 18   19  11.205717
# 19   20   8.646234
# 20   21   7.847352
# 21   22   9.796579
# 22   23  10.382167
# 23   24  10.706753
# 24   25  14.710015
# 25   26  10.874567
# 26   27  13.289078
# 27   28  16.388174
# 28   29  11.080497
# 29   30  11.161552
# 30   31  12.825996
# 31   32  12.726778
# 32   33  12.431287
# 33   34  10.652604
# 34   35  11.204418
# 35   36  10.112932
# 36   37   8.678981
# 37   38   8.677762
# 38   39   9.554259
# 39   40  10.637169
# 40   41   10.99842
# 41   42  14.665335
# 42   43  17.314727
# 43   44  16.085694
# 44   45  16.791808
# 45   46  21.218774
# 46   47  19.989776
# 47   48  23.516442
# 48   49  18.442045
# 49   50   20.07048
# 50   51  23.699459
# 51   52  18.571503

# %%
# Se crea el dataframe 'diagnosticosaño' con los nombres de los diferentes diagnosticos sin repeticion
diagnosticosaño = dataframeegresosaño['DIAG_INI'].value_counts()
# Se ordena del diagnostico con mayor numero de egresos al diagnostico con menor numero de egresos
diagnosticosaño = diagnosticosaño.sort_values(ascending = False)
# Se crea el dataframe 'cies2010' con los nombres de los diagnosticos, los numeros de las semanas, 
# y la cantidad de diagnosticos de dicha enfermedad en cada semana
ciesaño = dataframeegresosaño.groupby(['DIAG_INI', 'sem']).count()

# Se importan las librerias necesarias
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import string
# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib import style
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

import numpy as np

s_scaler = preprocessing.StandardScaler()
# Se crea la lista 'ind' con los indices de las semanas empezando con el 1
ind = []
n = len(semanas.index)
for i in range (n):
    ind.append(i+1)
    
# Se guardan las letras del abdcedario en mayusculas en la lista 'letras' para la agrupación de CIEs
letras = []
for letra in string.ascii_uppercase:
    letras.append(str(letra))
# Se inicia un contador para controlar la cantidad de graficos a generar
cont = 0
maximo = 5

datacorr = []
colors = []
spoke_labels = []

# Proceso de generación de las figuras
print('\n' + año)
for name in diagnosticosaño.index:
    if cont < maximo:
        dataframegraficoañocontaminantecie = pd.DataFrame()
        dataframegraficoañocontaminantecie[contaminante] = dataframesemanascontaminanteaño[contaminante]
        dataframegraficoañocontaminantecie = dataframegraficoañocontaminantecie.reindex(ind)
        
        dataframegraficoañocontaminantecie[name] = ciesaño['EGRESO'][name]
        for i in range (n):
            dataframegraficoañocontaminantecie[contaminante][i+1] = dataframesemanascontaminanteaño[contaminante][i]
        col_names = [contaminante, name]    
        
        # MODELO DE REGRESIÓN LINEAL
        # ==============================================================================
        spoke_labels.append(col_names[1])
        datos = pd.DataFrame(dataframegraficoañocontaminantecie, columns=col_names)
        datos = (datos - datos.min()) / (datos.max() - datos.min())
        # Gráfico
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        datos.plot(
            x    = col_names[0],
            y    = col_names[1],
            c    = 'firebrick',
            kind = "scatter",
            ax   = ax
        )
        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        print('\n\n Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        
        # Correlación lineal entre las dos variables
        # ==============================================================================
        corr_test = pearsonr(x = datos[col_names[0]].fillna(0), y =  datos[col_names[1]].fillna(0))
        print("Coeficiente de correlación de Pearson: ", corr_test[0])
        print("P-value: ", corr_test[1])

        datacorr.append(abs(corr_test[0]))
        if(corr_test[0] < 0):
            colors.append('r')
        else: 
            colors.append('b')

        # División de los datos en train y test
        # ==============================================================================
        X = datos[[col_names[0]]].fillna(0)
        y = datos[col_names[1]].fillna(0)

        X_train, X_test, y_train, y_test = train_test_split(
            X.values.reshape(-1,1),
            y.values.reshape(-1,1),
            train_size   = 0.8,
            random_state = 1234,
            shuffle      = True
        )
        
        X_train = sm.add_constant(X_train, prepend=True)
        modelo = sm.OLS(endog=y_train, exog=X_train)
        modelo = modelo.fit()
        print(modelo.summary())
        
        sml = modelo.summary().as_latex()
        namefile = 'modelos_latex/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.tex'
        f = open(namefile, 'w')
        with open(namefile, 'w') as f:
            f.write(sml)

        # Intervalos de confianza para los coeficientes del modelo
        # # ==============================================================================
        modelo.conf_int(alpha=0.05)

        # Predicciones con intervalo de confianza del 95%
        # # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones.head(4)        

        # Predicciones con intervalo de confianza del 95%
        # ==============================================================================
        predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
        predicciones['x'] = X_train[:, 1]
        predicciones['y'] = y_train
        predicciones = predicciones.sort_values('x')

        # Gráfico del modelo
        # ==============================================================================
        fig, ax = plt.subplots(figsize=(6, 3.84))

        ax.set_title('Contaminante ' + col_names[0] + ' & CIE ' + col_names[1])
        ax.set_xlabel(col_names[0])
        ax.set_ylabel(col_names[1])
        ax.scatter(predicciones['x'], predicciones['y'], marker='o', color = "gray")
        ax.plot(predicciones['x'], predicciones["mean"], linestyle='-', label="OLS")
        ax.plot(predicciones['x'], predicciones["mean_ci_lower"], linestyle='--', color='red', label="95% CI")
        ax.plot(predicciones['x'], predicciones["mean_ci_upper"], linestyle='--', color='red')
        ax.fill_between(predicciones['x'], predicciones["mean_ci_lower"], predicciones["mean_ci_upper"], alpha=0.1)
        ax.legend()

        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.eps', format='eps')
        plt.savefig(contaminante + '/' + 'regresion_lineal_' + col_names[0] + '&' + col_names[1] + '_' + año + '.jpg', format='jpg')

        # Error de test del modelo 
        # ==============================================================================
        X_test = sm.add_constant(X_test, prepend=True)
        predicciones = modelo.predict(exog = X_test)
        rmse = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False
            )
        print("")
        vmin = abs(y_train.min())
        vmax = abs(y_train.max())
        pval = vmin + vmax
        pe = (rmse*100)/pval
        print(f"El error (rmse) de test es: {rmse}")
        print(f"El porcentaje de error de test es: {pe}")


    cont = cont+1
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 2018
#
#
#  Contaminante NO2 & CIE O809
# Coeficiente de correlación de Pearson:  -0.009516853284595145
# P-value:  0.946613368595198
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.1178
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.733
# Time:                        07:42:34   Log-Likelihood:                 2.9871
# No. Observations:                  41   AIC:                            -1.974
# Df Residuals:                      39   BIC:                             1.453
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3914      0.061      6.453      0.000       0.269       0.514
# x1             0.0472      0.138      0.343      0.733      -0.231       0.325
# ==============================================================================
# Omnibus:                        1.257   Durbin-Watson:                   1.420
# Prob(Omnibus):                  0.533   Jarque-Bera (JB):                1.234
# Skew:                           0.377   Prob(JB):                        0.540
# Kurtosis:                       2.608   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.29570220261879043
# El porcentaje de error de test es: 31.768006902964647
#
#
#  Contaminante NO2 & CIE O829
# Coeficiente de correlación de Pearson:  0.05600875461898974
# P-value:  0.6933029734058451
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.1820
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.672
# Time:                        07:42:35   Log-Likelihood:                -5.1046
# No. Observations:                  41   AIC:                             14.21
# Df Residuals:                      39   BIC:                             17.64
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4252      0.074      5.753      0.000       0.276       0.575
# x1             0.0715      0.168      0.427      0.672      -0.267       0.410
# ==============================================================================
# Omnibus:                        6.085   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                2.971
# Skew:                           0.403   Prob(JB):                        0.226
# Kurtosis:                       1.956   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.2654344624489794
# El porcentaje de error de test es: 26.54344624489794
#
#
#  Contaminante NO2 & CIE K802
# Coeficiente de correlación de Pearson:  0.03792672267163846
# P-value:  0.7895144744570782
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                  0.004833
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.945
# Time:                        07:42:35   Log-Likelihood:                0.86994
# No. Observations:                  41   AIC:                             2.260
# Df Residuals:                      39   BIC:                             5.687
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4691      0.064      7.344      0.000       0.340       0.598
# x1             0.0101      0.145      0.070      0.945      -0.283       0.303
# ==============================================================================
# Omnibus:                        0.475   Durbin-Watson:                   1.565
# Prob(Omnibus):                  0.789   Jarque-Bera (JB):                0.593
# Skew:                           0.218   Prob(JB):                        0.743
# Kurtosis:                       2.604   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# El error (rmse) de test es: 0.15244583445612095
# El porcentaje de error de test es: 15.244583445612095
#
#
#  Contaminante NO2 & CIE O342
# Coeficiente de correlación de Pearson:  0.028280479805832086
# P-value:  0.8422504203517724
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                    0.2701
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):              0.606
# Time:                        07:42:35   Log-Likelihood:                -9.7534
# No. Observations:                  41   AIC:                             23.51
# Df Residuals:                      39   BIC:                             26.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3823      0.083      4.619      0.000       0.215       0.550
# x1             0.0975      0.188      0.520      0.606      -0.282       0.477
# ==============================================================================
# Omnibus:                        8.197   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                2.530
# Skew:                           0.152   Prob(JB):                        0.282
# Kurtosis:                       1.821   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.312654398954854
# El porcentaje de error de test es: 31.265439895485397
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  Contaminante NO2 & CIE N40X
# Coeficiente de correlación de Pearson:  -0.2376520109428491
# P-value:  0.0897961124031965
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.181
# Date:                Fri, 18 Mar 2022   Prob (F-statistic):             0.0823
# Time:                        07:42:35   Log-Likelihood:                 1.0077
# No. Observations:                  41   AIC:                             1.985
# Df Residuals:                      39   BIC:                             5.412
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5574      0.064      8.755      0.000       0.429       0.686
# x1            -0.2575      0.144     -1.784      0.082      -0.550       0.035
# ==============================================================================
# Omnibus:                        0.080   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.288
# Skew:                          -0.024   Prob(JB):                        0.866
# Kurtosis:                       2.592   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# El error (rmse) de test es: 0.2537801237969093
# El porcentaje de error de test es: 25.37801237969093

# %%
# Se importa el archivo creado
import visualization_spiderwebs

alldata = []
nd = len(datacorr)
for ii in range(nd):
    datatemp = []
    for yy in range(nd):
        if(ii==yy):
            datatemp.append(datacorr[ii])
        else: 
            datatemp.append(0)
    alldata.append(datatemp)
title = 'correlaciones_' + contaminante + '_' + año
visualization_spiderwebs.create_spiderwebs(alldata, 1, title, spoke_labels, colors, 'polygon')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
