# %% [markdown]
# # Verano FIME 2021

# %% [markdown]
# # INGRESOS HOSPITALARIOS

# %% [markdown]
# # Año 2015

# %%
año1 = '2015'
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['INGRE', 'DIAG_INI']
csvegresos = 'EGRESO_' + año1 + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums).dropna()
dataframeegresosaño
# Out:
#                        INGRE DIAG_INI
# 0        2014-12-31 00:00:00     C910
# 1        2014-12-28 00:00:00     C845
# 2        2014-12-23 00:00:00     C189
# 3        2015-01-02 00:00:00     C509
# 4        2015-01-01 00:00:00     C220
# ...                      ...      ...
# 2970807  2015-12-10 00:00:00     F195
# 2970808  2015-11-26 00:00:00     F203
# 2970809  2015-12-05 00:00:00     F259
# 2970810  2015-11-07 00:00:00     F050
# 2970811  2015-12-01 00:00:00     F250
#
# [2970812 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S'
dataframeegresosaño['INGRE'] = pd.to_datetime(dataframeegresosaño['INGRE'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año1) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['INGRE'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['INGRE'] = dataframeegresosaño['INGRE'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#              INGRE DIAG_INI  sem
# 0       2015-01-02     C509   53
# 1       2015-01-01     C220   53
# 2       2015-01-02     C069   53
# 3       2015-01-02     C169   53
# 4       2015-01-02     C509   53
# ...            ...      ...  ...
# 2906246 2015-12-10     F195   49
# 2906247 2015-11-26     F203   47
# 2906248 2015-12-05     F259   48
# 2906249 2015-11-07     F050   44
# 2906250 2015-12-01     F250   48
#
# [2906251 rows x 3 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     53972
# 2     57424
# 3     58387
# 4     57867
# 5     55741
# 6     58248
# 7     58265
# 8     58101
# 9     58948
# 10    58222
# 11    55594
# 12    58894
# 13    50559
# 14    56198
# 15    56719
# 16    57822
# 17    53943
# 18    53671
# 19    56827
# 20    56873
# 21    57413
# 22    57225
# 23    57622
# 24    56468
# 25    56469
# 26    56914
# 27    57779
# 28    57739
# 29    57290
# 30    57912
# 31    57855
# 32    58333
# 33    58817
# 34    59466
# 35    60153
# 36    60470
# 37    56164
# 38    60232
# 39    59464
# 40    60679
# 41    59082
# 42    57469
# 43    58043
# 44    55689
# 45    58637
# 46    54870
# 47    57464
# 48    56448
# 49    54565
# 50    50642
# 51    26700
# 53    19903
# Name: sem, dtype: int64

# %%
dataset1 = []
for i in semanas.index:
    dataset1.append(semanas[i])
dataset1
# Out:
# [53972,
#  57424,
#  58387,
#  57867,
#  55741,
#  58248,
#  58265,
#  58101,
#  58948,
#  58222,
#  55594,
#  58894,
#  50559,
#  56198,
#  56719,
#  57822,
#  53943,
#  53671,
#  56827,
#  56873,
#  57413,
#  57225,
#  57622,
#  56468,
#  56469,
#  56914,
#  57779,
#  57739,
#  57290,
#  57912,
#  57855,
#  58333,
#  58817,
#  59466,
#  60153,
#  60470,
#  56164,
#  60232,
#  59464,
#  60679,
#  59082,
#  57469,
#  58043,
#  55689,
#  58637,
#  54870,
#  57464,
#  56448,
#  54565,
#  50642,
#  26700,
#  19903]

# %% [markdown]
# # Año 2016

# %%
año2 = '2016'
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['INGRE', 'DIAG_INI']
csvegresos = 'EGRESO_' + año2 + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums).dropna()
dataframeegresosaño
# Out:
#                     INGRE DIAG_INI
# 0        12/30/2015 00:00     N185
# 1        12/31/2015 00:00     N185
# 2        12/31/2015 00:00     N185
# 3        01/02/2016 00:00     N185
# 4        01/02/2016 00:00     N185
# ...                   ...      ...
# 1048570  08/17/2016 00:00     E115
# 1048571  08/16/2016 00:00     O809
# 1048572  08/20/2016 00:00     O809
# 1048573  08/20/2016 00:00     O809
# 1048574  08/18/2016 00:00     O809
#
# [1048574 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%m/%d/%Y %H:%M'
dataframeegresosaño['INGRE'] = pd.to_datetime(dataframeegresosaño['INGRE'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año2) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['INGRE'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['INGRE'] = dataframeegresosaño['INGRE'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#              INGRE DIAG_INI  sem
# 0       2016-01-02     N185   52
# 1       2016-01-02     N185   52
# 2       2016-01-02     N185   52
# 3       2016-01-02     N185   52
# 4       2016-01-02     N185   52
# ...            ...      ...  ...
# 1024860 2016-08-17     E115   33
# 1024861 2016-08-16     O809   33
# 1024862 2016-08-20     O809   33
# 1024863 2016-08-20     O809   33
# 1024864 2016-08-18     O809   33
#
# [1024865 rows x 3 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     18612
# 2     19801
# 3     19815
# 4     19895
# 5     19497
# 6     20016
# 7     20183
# 8     20675
# 9     20661
# 10    20390
# 11    20570
# 12    16810
# 13    19868
# 14    20120
# 15    20305
# 16    19665
# 17    19980
# 18    19274
# 19    19373
# 20    20272
# 21    20542
# 22    20206
# 23    20279
# 24    19940
# 25    19926
# 26    19614
# 27    20032
# 28    20092
# 29    20397
# 30    20118
# 31    20087
# 32    20341
# 33    20434
# 34    20432
# 35    20903
# 36    21422
# 37    19796
# 38    21616
# 39    20858
# 40    20863
# 41    20488
# 42    20532
# 43    20002
# 44    18733
# 45    19965
# 46    19161
# 47    18398
# 48    19107
# 49    18416
# 50    17967
# 51    15296
# 52    13120
# Name: sem, dtype: int64

# %%
dataset2 = []
for i in semanas.index:
    dataset2.append(semanas[i])
dataset2
# Out:
# [18612,
#  19801,
#  19815,
#  19895,
#  19497,
#  20016,
#  20183,
#  20675,
#  20661,
#  20390,
#  20570,
#  16810,
#  19868,
#  20120,
#  20305,
#  19665,
#  19980,
#  19274,
#  19373,
#  20272,
#  20542,
#  20206,
#  20279,
#  19940,
#  19926,
#  19614,
#  20032,
#  20092,
#  20397,
#  20118,
#  20087,
#  20341,
#  20434,
#  20432,
#  20903,
#  21422,
#  19796,
#  21616,
#  20858,
#  20863,
#  20488,
#  20532,
#  20002,
#  18733,
#  19965,
#  19161,
#  18398,
#  19107,
#  18416,
#  17967,
#  15296,
#  13120]

# %% [markdown]
# # Año 2017

# %%
año3 = '2017'
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['INGRE', 'DIAG_INI']
csvegresos = 'EGRESO_' + año3 + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, sep='|', usecols=colums, nrows=1500000).dropna()
dataframeegresosaño
# Out:
#                        INGRE DIAG_INI
# 0        2017-02-12 00:00:00     O809
# 1        2017-03-10 00:00:00     O809
# 2        2017-04-06 00:00:00     E86X
# 3        2017-05-12 00:00:00     O809
# 4        2017-06-10 00:00:00     I219
# ...                      ...      ...
# 1499995  2017-08-03 00:00:00     O809
# 1499996  2017-08-03 00:00:00     O809
# 1499997  2017-08-04 00:00:00     O064
# 1499998  2017-08-03 00:00:00     O064
# 1499999  2017-08-03 00:00:00     O064
#
# [1499667 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S'
dataframeegresosaño['INGRE'] = pd.to_datetime(dataframeegresosaño['INGRE'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año3) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['INGRE'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['INGRE'] = dataframeegresosaño['INGRE'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#              INGRE DIAG_INI  sem
# 0       2017-02-12     O809    7
# 1       2017-03-10     O809   10
# 2       2017-04-06     E86X   14
# 3       2017-05-12     O809   19
# 4       2017-06-10     I219   23
# ...            ...      ...  ...
# 1488113 2017-08-03     O809   31
# 1488114 2017-08-03     O809   31
# 1488115 2017-08-04     O064   31
# 1488116 2017-08-03     O064   31
# 1488117 2017-08-03     O064   31
#
# [1488118 rows x 3 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     29642
# 2     31482
# 3     32620
# 4     31913
# 5     31806
# 6     30913
# 7     32163
# 8     31548
# 9     32193
# 10    31845
# 11    31067
# 12    29227
# 13    29087
# 14    28706
# 15    25164
# 16    27476
# 17    27402
# 18    24553
# 19    26376
# 20    27482
# 21    27121
# 22    26681
# 23    28125
# 24    27827
# 25    27864
# 26    27264
# 27    27440
# 28    27747
# 29    27415
# 30    26565
# 31    27961
# 32    28611
# 33    28637
# 34    28695
# 35    29119
# 36    29980
# 37    30642
# 38    30645
# 39    29506
# 40    30492
# 41    30629
# 42    30737
# 43    30023
# 44    28504
# 45    30304
# 46    29250
# 47    26734
# 48    27754
# 49    27968
# 50    25903
# 51    23180
# 52    16130
# Name: sem, dtype: int64

# %%
dataset3 = []
for i in semanas.index:
    dataset3.append(semanas[i])
dataset3
# Out:
# [29642,
#  31482,
#  32620,
#  31913,
#  31806,
#  30913,
#  32163,
#  31548,
#  32193,
#  31845,
#  31067,
#  29227,
#  29087,
#  28706,
#  25164,
#  27476,
#  27402,
#  24553,
#  26376,
#  27482,
#  27121,
#  26681,
#  28125,
#  27827,
#  27864,
#  27264,
#  27440,
#  27747,
#  27415,
#  26565,
#  27961,
#  28611,
#  28637,
#  28695,
#  29119,
#  29980,
#  30642,
#  30645,
#  29506,
#  30492,
#  30629,
#  30737,
#  30023,
#  28504,
#  30304,
#  29250,
#  26734,
#  27754,
#  27968,
#  25903,
#  23180,
#  16130]

# %% [markdown]
# # Año 2018

# %%
año4 = '2018'
# Se importan las librerias necesarias
import pandas as pd 

# Se cargan los datos de la base de datos 'EGRESO_'año'.csv'
colums = ['INGRE', 'DIAG_INI']
csvegresos = 'EGRESO_' + año4 + '.csv'
dataframeegresosaño = pd.read_csv(csvegresos, usecols=colums, nrows=1000000).dropna()
dataframeegresosaño
# Out:
#                           INGRE DIAG_INI
# 0       2018-03-09 00:00:00.000     Z524
# 1       2018-03-13 00:00:00.000     D259
# 2       2018-04-06 00:00:00.000     M169
# 3       2018-04-06 00:00:00.000     Q539
# 4       2018-04-16 00:00:00.000     N185
# ...                         ...      ...
# 999995  2018-04-22 00:00:00.000     E042
# 999996  2018-04-23 00:00:00.000     K802
# 999997  2018-04-25 00:00:00.000     K603
# 999998  2018-04-27 00:00:00.000     R69X
# 999999  2018-04-23 00:00:00.000     M179
#
# [1000000 rows x 2 columns]

# %%
# Se importan las librerias necesarias
from epiweeks import Week, date

# Se convierten los string a objetos datetime en 'dataframe'
strfdtoriginal = '%Y-%m-%d %H:%M:%S.000'
dataframeegresosaño['INGRE'] = pd.to_datetime(dataframeegresosaño['INGRE'], errors = 'coerce', format=strfdtoriginal)
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
numaño = int(año4) 
# Se agrega una columna con los numeros de semana
dataframeegresosaño['sem'] = dataframeegresosaño['INGRE'].apply(lambda x: date(x.year, x.month, x.day))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: Week.fromdate(x))
dataframeegresosaño['sem'] = dataframeegresosaño['sem'].apply(lambda x: x.week)
dataframeegresosaño['INGRE'] = dataframeegresosaño['INGRE'].apply(lambda x: x if(x.year==numaño) else pd.NaT)   
dataframeegresosaño = dataframeegresosaño.dropna()
dataframeegresosaño = dataframeegresosaño.reset_index(drop=True)
dataframeegresosaño
# Out:
#             INGRE DIAG_INI  sem
# 0      2018-03-09     Z524   10
# 1      2018-03-13     D259   11
# 2      2018-04-06     M169   14
# 3      2018-04-06     Q539   14
# 4      2018-04-16     N185   16
# ...           ...      ...  ...
# 992077 2018-04-22     E042   17
# 992078 2018-04-23     K802   17
# 992079 2018-04-25     K603   17
# 992080 2018-04-27     R69X   17
# 992081 2018-04-23     M179   17
#
# [992082 rows x 3 columns]

# %%
# Se forma el nuevo dataframe 'semanas' con el numero de semana del año y la cantidad de egresos en cada semana
semanas = dataframeegresosaño['sem'].value_counts()
semanas = semanas.sort_index()
semanas
# Out:
# 1     16103
# 2     19053
# 3     19417
# 4     19608
# 5     19332
# 6     18501
# 7     19536
# 8     19427
# 9     19683
# 10    19909
# 11    20007
# 12    19289
# 13    16812
# 14    19269
# 15    19795
# 16    19529
# 17    19577
# 18    18432
# 19    19231
# 20    20099
# 21    19808
# 22    19885
# 23    19468
# 24    18912
# 25    19007
# 26    18836
# 27    19238
# 28    19333
# 29    19610
# 30    19584
# 31    19147
# 32    19432
# 33    19322
# 34    20252
# 35    20106
# 36    20574
# 37    20183
# 38    20691
# 39    19870
# 40    20392
# 41    19736
# 42    19584
# 43    19538
# 44    17730
# 45    19674
# 46    18989
# 47    18175
# 48    18183
# 49    18149
# 50    17519
# 51    16440
# 52    12106
# Name: sem, dtype: int64

# %%
dataset4 = []
for i in semanas.index:
    dataset4.append(semanas[i])
dataset4
# Out:
# [16103,
#  19053,
#  19417,
#  19608,
#  19332,
#  18501,
#  19536,
#  19427,
#  19683,
#  19909,
#  20007,
#  19289,
#  16812,
#  19269,
#  19795,
#  19529,
#  19577,
#  18432,
#  19231,
#  20099,
#  19808,
#  19885,
#  19468,
#  18912,
#  19007,
#  18836,
#  19238,
#  19333,
#  19610,
#  19584,
#  19147,
#  19432,
#  19322,
#  20252,
#  20106,
#  20574,
#  20183,
#  20691,
#  19870,
#  20392,
#  19736,
#  19584,
#  19538,
#  17730,
#  19674,
#  18989,
#  18175,
#  18183,
#  18149,
#  17519,
#  16440,
#  12106]

# %%
# Se importa el archivo creado
import visualization_spiderwebs

# %%
alldata = []
alldata.append(dataset1)
alldata.append(dataset2)
alldata.append(dataset3)
alldata.append(dataset4)
title = 'Ingresos-hospitalarios'
spoke_labels = [año1, año2, año3, año4]
titles = titles = ['Semana 1', 'Semana 2', 'Semana 3', 'Semana 4', 'Semana 5', 'Semana 6']
colors = ['b', 'r', 'g', 'm', 'y', 'b']
visualization_spiderwebs.create_spiderwebs(alldata, 4, 6, title, titles, spoke_labels, colors, 'polygon')
